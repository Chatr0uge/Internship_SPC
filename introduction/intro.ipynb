# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('rose-pine')

# %%
N = 30
mesh = np.meshgrid(np.linspace(0, 1, N), np.linspace(0,2*np.pi, N), np.linspace(0,2*np.pi, N))
B = 1/mesh[0]
# Out:
# /tmp/ipykernel_5217/553581753.py:3: RuntimeWarning: divide by zero encountered in divide
#   B = 1/mesh[0]

# %%
R = 5
x,y,z = ((R + mesh[0] * np.cos(mesh[1])) * np.cos(mesh[2]), (R + mesh[0] * np.cos(mesh[1])) * np.sin(mesh[2]), mesh[0] * np.sin(mesh[1]))

# %%
B = 
mask = mesh_1[0]**2 + mesh_1[1]**2 < .4
mask2 = mesh_1[0]**2 + mesh_1[1]**2 >1

B[mask | mask2] = 0
# Out:
#   Cell In[148], line 1
#     B =
#         ^
# SyntaxError: invalid syntax

# %%
# %matplotlib widget

# %%
B.shape
# Out:
# (30, 30, 30)

# %%
fig, ax = plt.subplots()
ax.contour(mesh_1[0], mesh_1[1], B, levels = 62)
ax.set_aspect('equal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 ax.contour(mesh_1[0], mesh_1[1], B, levels = 62)
#       3 ax.set_aspect('equal')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6451, in Axes.contour(self, *args, **kwargs)
#    6442 """
#    6443 Plot contour lines.
#    6444
# ...

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(x, y, z, cmap = 'viridis', s = .2)
ax.set_aspect('equal')
# Out:
# /tmp/ipykernel_5217/337026584.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(x, y, z, cmap = 'viridis', s = .2)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
