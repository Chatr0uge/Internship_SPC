# %%
from lib_cuwa.lib_CUWA_core import CUWA
from lib_cuwa.gaussian_beam import GaussianBeam
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as sc 

plt.style.use('rose-pine')

# %%
C1 = CUWA(GPU_device_id=None)

# %%
beam1 = GaussianBeam(frequency_GHz = 90,
                                  mode          = 'X',
                                  origin        = np.array((0.05,0,0)),
                                  gaussian_focus= np.array((0.15,0.25,0)),
                                  waist_radius  = 0.035)

beam2= GaussianBeam(frequency_GHz = 110,
                                  mode          = 'X',
                                  origin        = np.array((0.0,0.03,0)),
                                  gaussian_focus= np.array((0.2,0.09,0)),
                                  waist_radius  = 0.015)

# %%
fig, ax = plt.subplots(1,1)
z = np.linspace(-1,1,100)
for beam in [beam1,beam2]:
    wr, zr = beam.Waist_radius, beam.Rayleigh_range
    w = wr*np.sqrt(1+np.square(z/zr))
    ax.plot(z,w, ':', label=f'{beam.frequency_GHz} GHz')
    ax.set_xlabel('z (m)')
    ax.set_ylabel('w (m)')
    ax.legend()

# %%
X,Y,Z = C1.set_comp_grid(omega_ref = beam2.w_0, 
                    vac_resolution = 12,
                            origin = np.array((0,0,0)), 
                               e_x = np.array((1,0,0)), 
                               e_y = np.array((0,1,0)), 
                           x_range = (0.0,0.25), 
                           y_range = (0.0,0.1), 
                          z_thick  =  0.0)

# %%
w_c = sc.e / sc.m_e * 2.4 + 0. * X
w_p = sc.e * np.sqrt(0.3e20 * np.fmax(Y,0)/np.max(Y) /(sc.m_e * sc.epsilon_0))
b_x = b_y = np.zeros_like(X)
b_z = np.ones_like(X)

# %%
C1.set_plasma_data(w_p, w_c, b_x, b_y, b_z, rampDown_width=25)
C1.set_antenna(beam,boundary='y_min'); C1.set_antenna(beam2,boundary='x_min')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 C1.set_plasma_data(w_p, w_c, b_x, b_y, b_z, rampDown_width=25)
#       2 C1.set_antenna(beam,boundary='y_min'); C1.set_antenna(beam2,boundary='x_min')
#
# File ~/lib_cuwa/src/lib_cuwa/lib_CUWA_core.py:181, in CUWA.set_plasma_data(self, w_pi, w_c_si, bx_si, by_si, bz_si, Te_nu, rampDown_width)
#     179 coef1             = self.w_p * self.w_p * self.dt * self.dt
#     180 bx_w = self.bx_s*self.w_c_s*self.dt; by_w = self.by_s*self.w_c_s*self.dt; bz_w = self.bz_s*self.w_c_s*self.dt;
# --> 181 self.plasma_data = [gpuarray.to_gpu(np.float32(field)) for field in [bx_w,by_w,bz_w,coef1]]
#     182 #self.nu   = nu
#     183 import scipy.constants as sc
#
# File ~/lib_cuwa/src/lib_cuwa/lib_CUWA_core.py:181, in <listcomp>(.0)
#     179 coef1             = self.w_p * self.w_p * self.dt * self.dt
#     180 bx_w = self.bx_s*self.w_c_s*self.dt; by_w = self.by_s*self.w_c_s*self.dt; bz_w = self.bz_s*self.w_c_s*self.dt;
# --> 181 self.plasma_data = [gpuarray.to_gpu(np.float32(field)) for field in [bx_w,by_w,bz_w,coef1]]
#     182 #self.nu   = nu
#     183 import scipy.constants as sc
#
# NameError: name 'gpuarray' is not defined
